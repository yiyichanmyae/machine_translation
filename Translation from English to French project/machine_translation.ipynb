# %% [markdown]
# # Artificial Intelligence Nanodegree
# ## Machine Translation Project
# In this notebook, sections that end with **'(IMPLEMENTATION)'** in the header indicate that the following blocks of code will require additional functionality which you must provide. Please be sure to read the instructions carefully!
#
# ## Introduction
# In this notebook, you will build a deep neural network that functions as part of an end-to-end machine translation pipeline. Your completed pipeline will accept English text as input and return the French translation.
#
# - **Preprocess** - You'll convert text to sequence of integers.
# - **Models** Create models which accepts a sequence of integers as input and returns a probability distribution over possible translations. After learning about the basic types of neural networks that are often used for machine translation, you will engage in your own investigations, to design your own model!
# - **Prediction** Run the model on English text.

# %%
# %load_ext autoreload
# %aimport helper, tests
# %autoreload 1

# %%
import collections

import helper
import numpy as np
import project_tests as tests

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model
from keras.layers import GRU, Input, Dense, TimeDistributed, Activation, RepeatVector, Bidirectional
from keras.layers.embeddings import Embedding
from keras.optimizers import Adam
from keras.losses import sparse_categorical_crossentropy
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Verify access to the GPU
# The following test applies only if you expect to be using a GPU, e.g., while running in a Udacity Workspace or using an AWS instance with GPU support. Run the next cell, and verify that the device_type is "GPU".
# - If the device is not GPU & you are running from a Udacity Workspace, then save your workspace with the icon at the top, then click "enable" at the bottom of the workspace.
# - If the device is not GPU & you are running from an AWS instance, then refer to the cloud computing instructions in the classroom to verify your setup steps.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/cpu:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13145444250061257843
# , name: "/gpu:0"
# device_type: "GPU"
# memory_limit: 357433344
# locality {
#   bus_id: 1
# }
# incarnation: 3112600791737323598
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0"
# ]

# %% [markdown]
# ## Dataset
# We begin by investigating the dataset that will be used to train and evaluate your pipeline.  The most common datasets used for machine translation are from [WMT](http://www.statmt.org/).  However, that will take a long time to train a neural network on.  We'll be using a dataset we created for this project that contains a small vocabulary.  You'll be able to train your model in a reasonable time with this dataset.
# ### Load Data
# The data is located in `data/small_vocab_en` and `data/small_vocab_fr`. The `small_vocab_en` file contains English sentences with their French translations in the `small_vocab_fr` file. Load the English and French data from these files from running the cell below.

# %%
# Load English data
english_sentences = helper.load_data('data/small_vocab_en')
# Load French data
french_sentences = helper.load_data('data/small_vocab_fr')

print('Dataset Loaded')
# Out:
# Dataset Loaded

# %% [markdown]
# ### Files
# Each line in `small_vocab_en` contains an English sentence with the respective translation in each line of `small_vocab_fr`.  View the first two lines from each file.

# %%
for sample_i in range(2):
    print('small_vocab_en Line {}:  {}'.format(sample_i + 1, english_sentences[sample_i]))
    print('small_vocab_fr Line {}:  {}'.format(sample_i + 1, french_sentences[sample_i]))
# Out:
# small_vocab_en Line 1:  new jersey is sometimes quiet during autumn , and it is snowy in april .
# small_vocab_fr Line 1:  new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# small_vocab_en Line 2:  the united states is usually chilly during july , and it is usually freezing in november .
# small_vocab_fr Line 2:  les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .

# %% [markdown]
# From looking at the sentences, you can see they have been preprocessed already.  The puncuations have been delimited using spaces. All the text have been converted to lowercase.  This should save you some time, but the text requires more preprocessing.
# ### Vocabulary
# The complexity of the problem is determined by the complexity of the vocabulary.  A more complex vocabulary is a more complex problem.  Let's look at the complexity of the dataset we'll be working with.

# %%
english_words_counter = collections.Counter([word for sentence in english_sentences for word in sentence.split()])
french_words_counter = collections.Counter([word for sentence in french_sentences for word in sentence.split()])

print('{} English words.'.format(len([word for sentence in english_sentences for word in sentence.split()])))
print('{} unique English words.'.format(len(english_words_counter)))
print('10 Most common words in the English dataset:')
print('"' + '" "'.join(list(zip(*english_words_counter.most_common(10)))[0]) + '"')
print()
print('{} French words.'.format(len([word for sentence in french_sentences for word in sentence.split()])))
print('{} unique French words.'.format(len(french_words_counter)))
print('10 Most common words in the French dataset:')
print('"' + '" "'.join(list(zip(*french_words_counter.most_common(10)))[0]) + '"')
# Out:
# 1823250 English words.
# 227 unique English words.
# 10 Most common words in the English dataset:
# "is" "," "." "in" "it" "during" "the" "but" "and" "sometimes"
#
# 1961295 French words.
# 355 unique French words.
# 10 Most common words in the French dataset:
# "est" "." "," "en" "il" "les" "mais" "et" "la" "parfois"

# %% [markdown]
# For comparison, _Alice's Adventures in Wonderland_ contains 2,766 unique words of a total of 15,500 words.
# ## Preprocess
# For this project, you won't use text data as input to your model. Instead, you'll convert the text into sequences of integers using the following preprocess methods:
# 1. Tokenize the words into ids
# 2. Add padding to make all the sequences the same length.
#
# Time to start preprocessing the data...
# ### Tokenize (IMPLEMENTATION)
# For a neural network to predict on text data, it first has to be turned into data it can understand. Text data like "dog" is a sequence of ASCII character encodings.  Since a neural network is a series of multiplication and addition operations, the input data needs to be number(s).
#
# We can turn each character into a number or each word into a number.  These are called character and word ids, respectively.  Character ids are used for character level models that generate text predictions for each character.  A word level model uses word ids that generate text predictions for each word.  Word level models tend to learn better, since they are lower in complexity, so we'll use those.
#
# Turn each sentence into a sequence of words ids using Keras's [`Tokenizer`](https://keras.io/preprocessing/text/#tokenizer) function. Use this function to tokenize `english_sentences` and `french_sentences` in the cell below.
#
# Running the cell will run `tokenize` on sample data and show output for debugging.

# %%
def tokenize(x):
    """
    Tokenize x
    :param x: List of sentences/strings to be tokenized
    :return: Tuple of (tokenized x data, tokenizer used to tokenize x)
    """
    # TODO: Implement
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(x)
    
    return tokenizer.texts_to_sequences(x), tokenizer

tests.test_tokenize(tokenize)

# Tokenize Example output
text_sentences = [
    'The quick brown fox jumps over the lazy dog .',
    'By Jove , my quick study of lexicography won a prize .',
    'This is a short sentence .']
text_tokenized, text_tokenizer = tokenize(text_sentences)
print(text_tokenizer.word_index)
print()
for sample_i, (sent, token_sent) in enumerate(zip(text_sentences, text_tokenized)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(sent))
    print('  Output: {}'.format(token_sent))
# Out:
# {'the': 1, 'quick': 2, 'a': 3, 'brown': 4, 'fox': 5, 'jumps': 6, 'over': 7, 'lazy': 8, 'dog': 9, 'by': 10, 'jove': 11, 'my': 12, 'study': 13, 'of': 14, 'lexicography': 15, 'won': 16, 'prize': 17, 'this': 18, 'is': 19, 'short': 20, 'sentence': 21}
#
# Sequence 1 in x
#   Input:  The quick brown fox jumps over the lazy dog .
#   Output: [1, 2, 4, 5, 6, 7, 1, 8, 9]
# Sequence 2 in x
#   Input:  By Jove , my quick study of lexicography won a prize .
#   Output: [10, 11, 12, 2, 13, 14, 15, 16, 3, 17]
# Sequence 3 in x
#   Input:  This is a short sentence .
#   Output: [18, 19, 3, 20, 21]

# %% [markdown]
# ### Padding (IMPLEMENTATION)
# When batching the sequence of word ids together, each sequence needs to be the same length.  Since sentences are dynamic in length, we can add padding to the end of the sequences to make them the same length.
#
# Make sure all the English sequences have the same length and all the French sequences have the same length by adding padding to the **end** of each sequence using Keras's [`pad_sequences`](https://keras.io/preprocessing/sequence/#pad_sequences) function.

# %%
def pad(x, length=None):
    """
    Pad x
    :param x: List of sequences.
    :param length: Length to pad the sequence to.  If None, use length of longest sequence in x.
    :return: Padded numpy array of sequences
    """
    # TODO: Implement
    if length == None:
        length = max([len(i) for i in x])
    
    return pad_sequences(x, maxlen=length, padding='post')
tests.test_pad(pad)

# Pad Tokenized output
test_pad = pad(text_tokenized)
for sample_i, (token_sent, pad_sent) in enumerate(zip(text_tokenized, test_pad)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(np.array(token_sent)))
    print('  Output: {}'.format(pad_sent))
# Out:
# Sequence 1 in x
#   Input:  [1 2 4 5 6 7 1 8 9]
#   Output: [1 2 4 5 6 7 1 8 9 0]
# Sequence 2 in x
#   Input:  [10 11 12  2 13 14 15 16  3 17]
#   Output: [10 11 12  2 13 14 15 16  3 17]
# Sequence 3 in x
#   Input:  [18 19  3 20 21]
#   Output: [18 19  3 20 21  0  0  0  0  0]

# %% [markdown]
# ### Preprocess Pipeline
# Your focus for this project is to build neural network architecture, so we won't ask you to create a preprocess pipeline.  Instead, we've provided you with the implementation of the `preprocess` function.

# %%
def preprocess(x, y):
    """
    Preprocess x and y
    :param x: Feature List of sentences
    :param y: Label List of sentences
    :return: Tuple of (Preprocessed x, Preprocessed y, x tokenizer, y tokenizer)
    """
    preprocess_x, x_tk = tokenize(x)
    preprocess_y, y_tk = tokenize(y)

    preprocess_x = pad(preprocess_x)
    preprocess_y = pad(preprocess_y)

    # Keras's sparse_categorical_crossentropy function requires the labels to be in 3 dimensions
    preprocess_y = preprocess_y.reshape(*preprocess_y.shape, 1)
    
    return preprocess_x, preprocess_y, x_tk, y_tk

preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer =\
    preprocess(english_sentences, french_sentences)
    
max_english_sequence_length = preproc_english_sentences.shape[1]
max_french_sequence_length = preproc_french_sentences.shape[1]
english_vocab_size = len(english_tokenizer.word_index)
french_vocab_size = len(french_tokenizer.word_index)

print('Data Preprocessed')
print("Max English sentence length:", max_english_sequence_length)
print("Max French sentence length:", max_french_sequence_length)
print("English vocabulary size:", english_vocab_size)
print("French vocabulary size:", french_vocab_size)
# Out:
# Data Preprocessed
# Max English sentence length: 15
# Max French sentence length: 21
# English vocabulary size: 199
# French vocabulary size: 344

# %%
print(preproc_french_sentences.shape)
# Out:
# (137861, 21, 1)

# %% [markdown]
# ## Models
# In this section, you will experiment with various neural network architectures.
# You will begin by training four relatively simple architectures.
# - Model 1 is a simple RNN
# - Model 2 is a RNN with Embedding
# - Model 3 is a Bidirectional RNN
# - Model 4 is an optional Encoder-Decoder RNN
#
# After experimenting with the four simple architectures, you will construct a deeper architecture that is designed to outperform all four models.
# ### Ids Back to Text
# The neural network will be translating the input to words ids, which isn't the final form we want.  We want the French translation.  The function `logits_to_text` will bridge the gab between the logits from the neural network to the French translation.  You'll be using this function to better understand the output of the neural network.

# %%
def logits_to_text(logits, tokenizer):
    """
    Turn logits from a neural network into text using the tokenizer
    :param logits: Logits from a neural network
    :param tokenizer: Keras Tokenizer fit on the labels
    :return: String that represents the text of the logits
    """
    index_to_words = {id: word for word, id in tokenizer.word_index.items()}
    index_to_words[0] = '<PAD>'

    print(np.argmax(logits,1))
    return ' '.join([index_to_words[prediction] for prediction in np.argmax(logits, 1)])

print('`logits_to_text` function loaded.')
# Out:
# `logits_to_text` function loaded.

# %% [markdown]
# ### Model 1: RNN (IMPLEMENTATION)
# ![RNN](images/rnn.png)
# A basic RNN model is a good baseline for sequence data.  In this model, you'll build a RNN that translates English to French.

# %%
def simple_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a basic RNN on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    print('inputs are : \ninput_shape : {}\noutput_sequence_length : {} \
          \nenglish_vocab_size : {}\nfrench_vocab_size : {}'.format(
        input_shape,
        output_sequence_length,
        english_vocab_size,
        french_vocab_size
    ))
    
    # Build the layers
    learning_rate = 1e-2
    
    input_seq = Input(input_shape[1:])
    
    rnn = GRU(64, return_sequences=True)(input_seq)
    logits = TimeDistributed(Dense(french_vocab_size))(rnn)
    
    
    model = Model(input_seq, Activation('softmax')(logits))
    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    return model
tests.test_simple_model(simple_model)

# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2], 1))
print('tmp_x shape ', tmp_x.shape)

# Train the neural network
simple_rnn_model = simple_model(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)
simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=50, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(simple_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# inputs are :
# input_shape : (137861, 21, 1)
# output_sequence_length : 21
# english_vocab_size : 199
# french_vocab_size : 344
# tmp_x shape  (137861, 21, 1)
# inputs are :
# input_shape : (137861, 21, 1)
# output_sequence_length : 21
# english_vocab_size : 199
# french_vocab_size : 344
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/50
# 110288/110288 [==============================] - 8s 70us/step - loss: 2.2573 - acc: 0.5088 - val_loss: nan - val_acc: 0.5849
# Epoch 2/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.5415 - acc: 0.6036 - val_loss: nan - val_acc: 0.6204
# Epoch 3/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.3898 - acc: 0.6290 - val_loss: nan - val_acc: 0.6348
# Epoch 4/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.3010 - acc: 0.6403 - val_loss: nan - val_acc: 0.6451
# Epoch 5/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.2363 - acc: 0.6490 - val_loss: nan - val_acc: 0.6488
# Epoch 6/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.1936 - acc: 0.6545 - val_loss: nan - val_acc: 0.6558
# Epoch 7/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.1634 - acc: 0.6594 - val_loss: nan - val_acc: 0.6656
# Epoch 8/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.1396 - acc: 0.6636 - val_loss: nan - val_acc: 0.6605
# Epoch 9/50
# 110288/110288 [==============================] - 7s 67us/step - loss: 1.1191 - acc: 0.6676 - val_loss: nan - val_acc: 0.6620
# Epoch 10/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.1040 - acc: 0.6721 - val_loss: nan - val_acc: 0.6744
# Epoch 11/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.0846 - acc: 0.6792 - val_loss: nan - val_acc: 0.6849
# Epoch 12/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.0698 - acc: 0.6837 - val_loss: nan - val_acc: 0.6912
# Epoch 13/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.0490 - acc: 0.6912 - val_loss: nan - val_acc: 0.6960
# Epoch 14/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.0327 - acc: 0.6962 - val_loss: nan - val_acc: 0.6981
# Epoch 15/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.0212 - acc: 0.6991 - val_loss: nan - val_acc: 0.6971
# Epoch 16/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.0066 - acc: 0.7032 - val_loss: nan - val_acc: 0.7068
# Epoch 17/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 1.0004 - acc: 0.7027 - val_loss: nan - val_acc: 0.7067
# Epoch 18/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9827 - acc: 0.7086 - val_loss: nan - val_acc: 0.7061
# Epoch 19/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9705 - acc: 0.7113 - val_loss: nan - val_acc: 0.7074
# Epoch 20/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9616 - acc: 0.7133 - val_loss: nan - val_acc: 0.7137
# Epoch 21/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9524 - acc: 0.7153 - val_loss: nan - val_acc: 0.7167
# Epoch 22/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9460 - acc: 0.7164 - val_loss: nan - val_acc: 0.7113
# Epoch 23/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9385 - acc: 0.7179 - val_loss: nan - val_acc: 0.7156
# Epoch 24/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9368 - acc: 0.7179 - val_loss: nan - val_acc: 0.7262
# Epoch 25/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9200 - acc: 0.7228 - val_loss: nan - val_acc: 0.7267
# Epoch 26/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9166 - acc: 0.7225 - val_loss: nan - val_acc: 0.7303
# Epoch 27/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9055 - acc: 0.7262 - val_loss: nan - val_acc: 0.7221
# Epoch 28/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9000 - acc: 0.7272 - val_loss: nan - val_acc: 0.7285
# Epoch 29/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9243 - acc: 0.7185 - val_loss: nan - val_acc: 0.7275
# Epoch 30/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8913 - acc: 0.7297 - val_loss: nan - val_acc: 0.7344
# Epoch 31/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8876 - acc: 0.7302 - val_loss: nan - val_acc: 0.7269
# Epoch 32/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8835 - acc: 0.7307 - val_loss: nan - val_acc: 0.7331
# Epoch 33/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8924 - acc: 0.7276 - val_loss: nan - val_acc: 0.7320
# Epoch 34/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8729 - acc: 0.7333 - val_loss: nan - val_acc: 0.7357
# Epoch 35/50
# 110288/110288 [==============================] - 7s 67us/step - loss: 0.8659 - acc: 0.7358 - val_loss: nan - val_acc: 0.7375
# Epoch 36/50
# 110288/110288 [==============================] - 7s 67us/step - loss: 0.8650 - acc: 0.7352 - val_loss: nan - val_acc: 0.7355
# Epoch 37/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.9146 - acc: 0.7185 - val_loss: nan - val_acc: 0.7037
# Epoch 38/50
# 110288/110288 [==============================] - 7s 67us/step - loss: 0.8820 - acc: 0.7294 - val_loss: nan - val_acc: 0.7166
# Epoch 39/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8685 - acc: 0.7351 - val_loss: nan - val_acc: 0.7350
# Epoch 40/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8604 - acc: 0.7372 - val_loss: nan - val_acc: 0.7363
# Epoch 41/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8506 - acc: 0.7400 - val_loss: nan - val_acc: 0.7416
# Epoch 42/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8470 - acc: 0.7403 - val_loss: nan - val_acc: 0.7378
# Epoch 43/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8710 - acc: 0.7310 - val_loss: nan - val_acc: 0.7419
# Epoch 44/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8423 - acc: 0.7418 - val_loss: nan - val_acc: 0.7403
# Epoch 45/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8388 - acc: 0.7422 - val_loss: nan - val_acc: 0.7447
# Epoch 46/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8352 - acc: 0.7433 - val_loss: nan - val_acc: 0.7440
# Epoch 47/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8278 - acc: 0.7452 - val_loss: nan - val_acc: 0.7432
# Epoch 48/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8522 - acc: 0.7363 - val_loss: nan - val_acc: 0.7464
# Epoch 49/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8255 - acc: 0.7453 - val_loss: nan - val_acc: 0.7433
# Epoch 50/50
# 110288/110288 [==============================] - 7s 66us/step - loss: 0.8172 - acc: 0.7482 - val_loss: nan - val_acc: 0.7495
# [35 34  1  8 21  2 11 22 47  1  1  1  2  0  0  0  0  0  0  0  0]
# new jersey est parfois chaud en l' de mai est est est en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 2: Embedding (IMPLEMENTATION)
# ![RNN](images/embedding.png)
# You've turned the words into ids, but there's a better representation of a word.  This is called word embeddings.  An embedding is a vector representation of the word that is close to similar words in n-dimensional space, where the n represents the size of the embedding vectors.
#
# In this model, you'll create a RNN model using embedding.

# %%
from keras.models import Sequential
def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a RNN model using word embedding on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # Implement
    learning_rate = 1e-3
    
    emb = Embedding(input_dim=english_vocab_size, output_dim=64, input_length=input_shape[1])
    rnn = GRU(128, return_sequences=True, activation='tanh')
    logits =TimeDistributed(Dense(french_vocab_size, activation='softmax'))
    
    model = Sequential()
    model.add(emb)
    model.add(rnn)
    model.add(logits)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    
    return model
tests.test_embed_model(embed_model)


# Reshape the input
print(preproc_english_sentences.shape)
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
print(tmp_x.shape)
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2]))
print(tmp_x.shape)


# Train the neural network
embedded_rnn_model = embed_model(
    input_shape = tmp_x.shape, 
    output_sequence_length = max_french_sequence_length, 
    english_vocab_size = english_vocab_size, 
    french_vocab_size = french_vocab_size
)
print(embedded_rnn_model.summary())
embedded_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=2048, epochs=50, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(embedded_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# (137861, 15)
# (137861, 21)
# (137861, 21)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_15 (Embedding)     (None, 21, 64)            12736
# _________________________________________________________________
# gru_15 (GRU)                 (None, 21, 128)           74112
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 21, 344)           44376
# =================================================================
# Total params: 131,224
# Trainable params: 131,224
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/50
# 110288/110288 [==============================] - 8s 70us/step - loss: 4.0836 - acc: 0.3995 - val_loss: nan - val_acc: 0.4093
# Epoch 2/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 2.9162 - acc: 0.4088 - val_loss: nan - val_acc: 0.4136
# Epoch 3/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 2.6166 - acc: 0.4587 - val_loss: nan - val_acc: 0.4885
# Epoch 4/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 2.2898 - acc: 0.5169 - val_loss: nan - val_acc: 0.5427
# Epoch 5/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 1.8349 - acc: 0.5696 - val_loss: nan - val_acc: 0.6091
# Epoch 6/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 1.5100 - acc: 0.6319 - val_loss: nan - val_acc: 0.6534
# Epoch 7/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 1.3283 - acc: 0.6735 - val_loss: nan - val_acc: 0.6999
# Epoch 8/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 1.1750 - acc: 0.7209 - val_loss: nan - val_acc: 0.7388
# Epoch 9/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 1.0292 - acc: 0.7536 - val_loss: nan - val_acc: 0.7663
# Epoch 10/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.9022 - acc: 0.7746 - val_loss: nan - val_acc: 0.7840
# Epoch 11/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.7987 - acc: 0.7919 - val_loss: nan - val_acc: 0.8000
# Epoch 12/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.7186 - acc: 0.8068 - val_loss: nan - val_acc: 0.8132
# Epoch 13/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.6519 - acc: 0.8218 - val_loss: nan - val_acc: 0.8275
# Epoch 14/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.6011 - acc: 0.8331 - val_loss: nan - val_acc: 0.8369
# Epoch 15/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.5595 - acc: 0.8428 - val_loss: nan - val_acc: 0.8485
# Epoch 16/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.5238 - acc: 0.8519 - val_loss: nan - val_acc: 0.8557
# Epoch 17/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.4967 - acc: 0.8584 - val_loss: nan - val_acc: 0.8627
# Epoch 18/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.4692 - acc: 0.8654 - val_loss: nan - val_acc: 0.8690
# Epoch 19/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.4471 - acc: 0.8712 - val_loss: nan - val_acc: 0.8732
# Epoch 20/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.4272 - acc: 0.8759 - val_loss: nan - val_acc: 0.8774
# Epoch 21/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.4103 - acc: 0.8798 - val_loss: nan - val_acc: 0.8819
# Epoch 22/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.3930 - acc: 0.8845 - val_loss: nan - val_acc: 0.8849
# Epoch 23/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3786 - acc: 0.8882 - val_loss: nan - val_acc: 0.8893
# Epoch 24/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3658 - acc: 0.8913 - val_loss: nan - val_acc: 0.8908
# Epoch 25/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3538 - acc: 0.8945 - val_loss: nan - val_acc: 0.8946
# Epoch 26/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3456 - acc: 0.8965 - val_loss: nan - val_acc: 0.8972
# Epoch 27/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3334 - acc: 0.8998 - val_loss: nan - val_acc: 0.8995
# Epoch 28/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3255 - acc: 0.9017 - val_loss: nan - val_acc: 0.9008
# Epoch 29/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3184 - acc: 0.9035 - val_loss: nan - val_acc: 0.9039
# Epoch 30/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3095 - acc: 0.9060 - val_loss: nan - val_acc: 0.9060
# Epoch 31/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.3041 - acc: 0.9073 - val_loss: nan - val_acc: 0.9056
# Epoch 32/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2973 - acc: 0.9089 - val_loss: nan - val_acc: 0.9079
# Epoch 33/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2916 - acc: 0.9105 - val_loss: nan - val_acc: 0.9100
# Epoch 34/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.2858 - acc: 0.9120 - val_loss: nan - val_acc: 0.9109
# Epoch 35/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2804 - acc: 0.9134 - val_loss: nan - val_acc: 0.9115
# Epoch 36/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2766 - acc: 0.9142 - val_loss: nan - val_acc: 0.9141
# Epoch 37/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2720 - acc: 0.9154 - val_loss: nan - val_acc: 0.9141
# Epoch 38/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2662 - acc: 0.9172 - val_loss: nan - val_acc: 0.9151
# Epoch 39/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2642 - acc: 0.9174 - val_loss: nan - val_acc: 0.9143
# Epoch 40/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2610 - acc: 0.9181 - val_loss: nan - val_acc: 0.9170
# Epoch 41/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2565 - acc: 0.9194 - val_loss: nan - val_acc: 0.9184
# Epoch 42/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2515 - acc: 0.9208 - val_loss: nan - val_acc: 0.9193
# Epoch 43/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2488 - acc: 0.9215 - val_loss: nan - val_acc: 0.9196
# Epoch 44/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.2467 - acc: 0.9220 - val_loss: nan - val_acc: 0.9190
# Epoch 45/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.2437 - acc: 0.9227 - val_loss: nan - val_acc: 0.9192
# Epoch 46/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.2418 - acc: 0.9231 - val_loss: nan - val_acc: 0.9215
# Epoch 47/50
# 110288/110288 [==============================] - 7s 64us/step - loss: 0.2380 - acc: 0.9242 - val_loss: nan - val_acc: 0.9218
# Epoch 48/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2378 - acc: 0.9239 - val_loss: nan - val_acc: 0.9214
# Epoch 49/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2345 - acc: 0.9249 - val_loss: nan - val_acc: 0.9230
# Epoch 50/50
# 110288/110288 [==============================] - 7s 63us/step - loss: 0.2327 - acc: 0.9252 - val_loss: nan - val_acc: 0.9238
# [ 35  34   1   8  67   2  11  24   6   3   1 112   2  50   0   0   0   0
#    0   0   0]
# new jersey est parfois calme en l' automne et il est neigeux en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 3: Bidirectional RNNs (IMPLEMENTATION)
# ![RNN](images/bidirectional.png)
# One restriction of a RNN is that it can't see the future input, only the past.  This is where bidirectional recurrent neural networks come in.  They are able to see the future data.

# %%
from keras.models import Sequential

def bd_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a bidirectional RNN model on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # Implement
    learning_rate = 1e-3
    
    emb = Embedding(input_dim=english_vocab_size, output_dim=64, input_length=input_shape[1])
    rnn = Bidirectional(GRU(128, return_sequences=True, activation='tanh', dropout=0.1))
    logits =TimeDistributed(Dense(french_vocab_size, activation='softmax'))
    
    model = Sequential()
    model.add(emb)
    model.add(rnn)
    model.add(logits)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    
    return model
tests.test_embed_model(bd_model)


# Reshape the input
print(preproc_english_sentences.shape)
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
print(tmp_x.shape)
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2]))
print(tmp_x.shape)


# Train the neural network
embedded_bd_rnn_model = bd_model(
    input_shape = tmp_x.shape, 
    output_sequence_length = max_french_sequence_length, 
    english_vocab_size = english_vocab_size, 
    french_vocab_size = french_vocab_size
)
print(embedded_bd_rnn_model.summary())
embedded_bd_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=2048, epochs=30, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(embedded_bd_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# (137861, 15)
# (137861, 21)
# (137861, 21)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 21, 64)            12736
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 21, 256)           148224
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 21, 344)           88408
# =================================================================
# Total params: 249,368
# Trainable params: 249,368
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/30
# 110288/110288 [==============================] - 14s 126us/step - loss: 3.7759 - acc: 0.4182 - val_loss: nan - val_acc: 0.4646
# Epoch 2/30
# 110288/110288 [==============================] - 11s 102us/step - loss: 2.5454 - acc: 0.4704 - val_loss: nan - val_acc: 0.4794
# Epoch 3/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 2.3332 - acc: 0.4994 - val_loss: nan - val_acc: 0.5322
# Epoch 4/30
# 110288/110288 [==============================] - 11s 102us/step - loss: 1.8563 - acc: 0.5655 - val_loss: nan - val_acc: 0.5946
# Epoch 5/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 1.5107 - acc: 0.6141 - val_loss: nan - val_acc: 0.6428
# Epoch 6/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 1.2730 - acc: 0.6784 - val_loss: nan - val_acc: 0.7127
# Epoch 7/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 1.0683 - acc: 0.7298 - val_loss: nan - val_acc: 0.7527
# Epoch 8/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.9203 - acc: 0.7617 - val_loss: nan - val_acc: 0.7790
# Epoch 9/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.8105 - acc: 0.7824 - val_loss: nan - val_acc: 0.7922
# Epoch 10/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.7279 - acc: 0.7985 - val_loss: nan - val_acc: 0.8108
# Epoch 11/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.6570 - acc: 0.8142 - val_loss: nan - val_acc: 0.8253
# Epoch 12/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.5983 - acc: 0.8273 - val_loss: nan - val_acc: 0.8386
# Epoch 13/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.5448 - acc: 0.8402 - val_loss: nan - val_acc: 0.8529
# Epoch 14/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.4992 - acc: 0.8524 - val_loss: nan - val_acc: 0.8648
# Epoch 15/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.4591 - acc: 0.8632 - val_loss: nan - val_acc: 0.8749
# Epoch 16/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.4257 - acc: 0.8729 - val_loss: nan - val_acc: 0.8858
# Epoch 17/30
# 110288/110288 [==============================] - 11s 104us/step - loss: 0.3958 - acc: 0.8821 - val_loss: nan - val_acc: 0.8935
# Epoch 18/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.3715 - acc: 0.8891 - val_loss: nan - val_acc: 0.9010
# Epoch 19/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.3472 - acc: 0.8969 - val_loss: nan - val_acc: 0.9079
# Epoch 20/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.3267 - acc: 0.9031 - val_loss: nan - val_acc: 0.9136
# Epoch 21/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.3084 - acc: 0.9085 - val_loss: nan - val_acc: 0.9187
# Epoch 22/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2921 - acc: 0.9135 - val_loss: nan - val_acc: 0.9226
# Epoch 23/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2772 - acc: 0.9181 - val_loss: nan - val_acc: 0.9278
# Epoch 24/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2643 - acc: 0.9220 - val_loss: nan - val_acc: 0.9311
# Epoch 25/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2517 - acc: 0.9257 - val_loss: nan - val_acc: 0.9339
# Epoch 26/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2411 - acc: 0.9289 - val_loss: nan - val_acc: 0.9374
# Epoch 27/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2313 - acc: 0.9317 - val_loss: nan - val_acc: 0.9400
# Epoch 28/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2215 - acc: 0.9347 - val_loss: nan - val_acc: 0.9421
# Epoch 29/30
# 110288/110288 [==============================] - 11s 103us/step - loss: 0.2134 - acc: 0.9371 - val_loss: nan - val_acc: 0.9425
# Epoch 30/30
# 110288/110288 [==============================] - 10s 94us/step - loss: 0.2076 - acc: 0.9387 - val_loss: nan - val_acc: 0.9450
# [35 34  1  8 67 37 11 24  3  3  1  2 50  0  0  0  0  0  0  0  0]
# new jersey est parfois calme pendant l' automne il il est en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 4: Encoder-Decoder (OPTIONAL)
# Time to look at encoder-decoder models.  This model is made up of an encoder and decoder. The encoder creates a matrix representation of the sentence.  The decoder takes this matrix as input and predicts the translation as output.
#
# Create an encoder-decoder model in the cell below.

# %%
from keras.models import Sequential

def encdec_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train an encoder-decoder model on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # Implement
    
    learning_rate = 1e-3
    
    emb = Embedding(input_dim=english_vocab_size, output_dim=64, input_length=input_shape[1])
    rnn1 = GRU(128, return_sequences=False, activation='tanh', dropout=0.1)
    repv = RepeatVector(output_sequence_length)
    rnn2 = GRU(128, return_sequences=True, activation='tanh', dropout=0.1)
    logits =TimeDistributed(Dense(french_vocab_size, activation='softmax'))
    
    model = Sequential()
    model.add(emb)
    model.add(rnn1)
    model.add(repv)
    model.add(rnn2)
    model.add(logits)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    
    return model
tests.test_embed_model(encdec_model)


# Reshape the input
print(preproc_english_sentences.shape)
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
print(tmp_x.shape)
tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2]))
print(tmp_x.shape)


# Train the neural network
encdoc_rnn_model = encdec_model(
    input_shape = tmp_x.shape, 
    output_sequence_length = max_french_sequence_length, 
    english_vocab_size = english_vocab_size, 
    french_vocab_size = french_vocab_size
)
print(encdoc_rnn_model.summary())
encdoc_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=2048, epochs=40, validation_split=0.2)

# Print prediction(s)
print(logits_to_text(encdoc_rnn_model.predict(tmp_x[:1])[0], french_tokenizer))
# Out:
# (137861, 15)
# (137861, 21)
# (137861, 21)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 21, 64)            12736
# _________________________________________________________________
# gru_7 (GRU)                  (None, 128)               74112
# _________________________________________________________________
# repeat_vector_4 (RepeatVecto (None, 21, 128)           0
# _________________________________________________________________
# gru_8 (GRU)                  (None, 21, 128)           98688
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 21, 344)           44376
# =================================================================
# Total params: 229,912
# Trainable params: 229,912
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/40
# 110288/110288 [==============================] - 12s 106us/step - loss: 3.7381 - acc: 0.4048 - val_loss: nan - val_acc: 0.4208
# Epoch 2/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 2.8321 - acc: 0.4401 - val_loss: nan - val_acc: 0.4459
# Epoch 3/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 2.5946 - acc: 0.4556 - val_loss: nan - val_acc: 0.4726
# Epoch 4/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 2.4226 - acc: 0.4792 - val_loss: nan - val_acc: 0.4992
# Epoch 5/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 2.2572 - acc: 0.5044 - val_loss: nan - val_acc: 0.5241
# Epoch 6/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 2.1352 - acc: 0.5245 - val_loss: nan - val_acc: 0.5389
# Epoch 7/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 2.0244 - acc: 0.5427 - val_loss: nan - val_acc: 0.5484
# Epoch 8/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.9277 - acc: 0.5516 - val_loss: nan - val_acc: 0.5565
# Epoch 9/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.8540 - acc: 0.5564 - val_loss: nan - val_acc: 0.5640
# Epoch 10/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.7942 - acc: 0.5631 - val_loss: nan - val_acc: 0.5687
# Epoch 11/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.7554 - acc: 0.5674 - val_loss: nan - val_acc: 0.5697
# Epoch 12/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.7176 - acc: 0.5716 - val_loss: nan - val_acc: 0.5764
# Epoch 13/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.6877 - acc: 0.5743 - val_loss: nan - val_acc: 0.5783
# Epoch 14/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.6585 - acc: 0.5767 - val_loss: nan - val_acc: 0.5803
# Epoch 15/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.6233 - acc: 0.5794 - val_loss: nan - val_acc: 0.5791
# Epoch 16/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.5123 - acc: 0.5935 - val_loss: nan - val_acc: 0.6055
# Epoch 17/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.4317 - acc: 0.6050 - val_loss: nan - val_acc: 0.6112
# Epoch 18/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.3945 - acc: 0.6107 - val_loss: nan - val_acc: 0.6161
# Epoch 19/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.3617 - acc: 0.6178 - val_loss: nan - val_acc: 0.6246
# Epoch 20/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.3303 - acc: 0.6251 - val_loss: nan - val_acc: 0.6327
# Epoch 21/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.3057 - acc: 0.6302 - val_loss: nan - val_acc: 0.6347
# Epoch 22/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.2813 - acc: 0.6352 - val_loss: nan - val_acc: 0.6409
# Epoch 23/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.2586 - acc: 0.6390 - val_loss: nan - val_acc: 0.6433
# Epoch 24/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.2415 - acc: 0.6421 - val_loss: nan - val_acc: 0.6484
# Epoch 25/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.2234 - acc: 0.6455 - val_loss: nan - val_acc: 0.6519
# Epoch 26/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.2082 - acc: 0.6493 - val_loss: nan - val_acc: 0.6578
# Epoch 27/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.1854 - acc: 0.6556 - val_loss: nan - val_acc: 0.6639
# Epoch 28/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.1601 - acc: 0.6642 - val_loss: nan - val_acc: 0.6736
# Epoch 29/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.1380 - acc: 0.6722 - val_loss: nan - val_acc: 0.6786
# Epoch 30/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.1168 - acc: 0.6778 - val_loss: nan - val_acc: 0.6849
# Epoch 31/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.0974 - acc: 0.6817 - val_loss: nan - val_acc: 0.6854
# Epoch 32/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.0826 - acc: 0.6844 - val_loss: nan - val_acc: 0.6901
# Epoch 33/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.0682 - acc: 0.6880 - val_loss: nan - val_acc: 0.6946
# Epoch 34/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.0608 - acc: 0.6899 - val_loss: nan - val_acc: 0.6966
# Epoch 35/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.0430 - acc: 0.6940 - val_loss: nan - val_acc: 0.7007
# Epoch 36/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.0309 - acc: 0.6969 - val_loss: nan - val_acc: 0.7019
# Epoch 37/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 1.0196 - acc: 0.6995 - val_loss: nan - val_acc: 0.7044
# Epoch 38/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 1.0145 - acc: 0.7005 - val_loss: nan - val_acc: 0.7058
# Epoch 39/40
# 110288/110288 [==============================] - 11s 99us/step - loss: 0.9972 - acc: 0.7041 - val_loss: nan - val_acc: 0.7120
# Epoch 40/40
# 110288/110288 [==============================] - 11s 100us/step - loss: 0.9849 - acc: 0.7069 - val_loss: nan - val_acc: 0.7140
# [35 34  1  9 21  2 98  5  3  1  8  1  2  2  0  0  0  0  0  0  0]
# new jersey est jamais chaud en l'automne mais il est parfois est en en <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ### Model 5: Custom (IMPLEMENTATION)
# Use everything you learned from the previous models to create a model that incorporates embedding and a bidirectional rnn into one model.

# %%
from keras.models import Sequential
def model_final(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a model that incorporates embedding, encoder-decoder, and bidirectional RNN on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # Implement
    
    learning_rate = 1e-3
    
    emb = Embedding(input_dim=english_vocab_size, output_dim=128, input_length=input_shape[1])
    rnn1 = Bidirectional(GRU(128, return_sequences=True, activation='tanh', dropout=0.1))
    rnn2 = GRU(128, return_sequences=True, activation='tanh', dropout=0.1)
    logits =TimeDistributed(Dense(french_vocab_size, activation='softmax'))
    
    model = Sequential()
    model.add(emb)
    model.add(rnn1)
    model.add(rnn2)
    model.add(logits)
    model.compile(
        loss=sparse_categorical_crossentropy,
        optimizer=Adam(learning_rate),
        metrics=['accuracy']
    )
    
    return model
tests.test_embed_model(model_final)
print('Final Model Loaded')
# Out:
# Final Model Loaded

# %% [markdown]
# ## Prediction (IMPLEMENTATION)

# %%
def final_predictions(x, y, x_tk, y_tk):
    """
    Gets predictions using the final model
    :param x: Preprocessed English data
    :param y: Preprocessed French data
    :param x_tk: English tokenizer
    :param y_tk: French tokenizer
    """
    print(x.shape)
    x = pad(x, y.shape[1])
    print(x.shape)
    print(y.shape)
    # Train neural network using model_final
    model = model_final(
        input_shape = x.shape, 
        output_sequence_length = y.shape[1], 
        english_vocab_size = len(x_tk.word_index), 
        french_vocab_size = len(y_tk.word_index)
    )
    print(model.summary())

    model.fit(
        x,
        y,
        batch_size = 2048,
        epochs =70,
        validation_split = 0.2
    )

    
    ## DON'T EDIT ANYTHING BELOW THIS LINE
    y_id_to_word = {value: key for key, value in y_tk.word_index.items()}
    y_id_to_word[0] = '<PAD>'

    sentence = 'he saw a old yellow truck'
    sentence = [x_tk.word_index[word] for word in sentence.split()]
    sentence = pad_sequences([sentence], maxlen=x.shape[-1], padding='post')    
    sentences = np.array([sentence[0], x[0]])
    
    predictions = model.predict(sentences, len(sentences))

    print('Sample 1:')
    print(' '.join([y_id_to_word[np.argmax(x)] for x in predictions[0]]))
    print('Il a vu un vieux camion jaune')
    
    print('Sample 2:')
    print(' '.join([y_id_to_word[np.argmax(x)] for x in predictions[1]]))
    print(' '.join([y_id_to_word[np.max(x)] for x in y[0]]))


final_predictions(preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer)
# Out:
# (137861, 15)
# (137861, 21)
# (137861, 21, 1)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 21, 128)           25472
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 21, 256)           197376
# _________________________________________________________________
# gru_14 (GRU)                 (None, 21, 128)           147840
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 21, 344)           44376
# =================================================================
# Total params: 415,064
# Trainable params: 415,064
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 110288 samples, validate on 27573 samples
# Epoch 1/70
# 110288/110288 [==============================] - 18s 164us/step - loss: 3.5633 - acc: 0.4097 - val_loss: nan - val_acc: 0.4452
# Epoch 2/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 2.5122 - acc: 0.4795 - val_loss: nan - val_acc: 0.5092
# Epoch 3/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 1.9883 - acc: 0.5545 - val_loss: nan - val_acc: 0.6001
# Epoch 4/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 1.4765 - acc: 0.6403 - val_loss: nan - val_acc: 0.6767
# Epoch 5/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 1.2252 - acc: 0.6979 - val_loss: nan - val_acc: 0.7228
# Epoch 6/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 1.0533 - acc: 0.7381 - val_loss: nan - val_acc: 0.7604
# Epoch 7/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.9104 - acc: 0.7710 - val_loss: nan - val_acc: 0.7923
# Epoch 8/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.7846 - acc: 0.8026 - val_loss: nan - val_acc: 0.8227
# Epoch 9/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.6770 - acc: 0.8267 - val_loss: nan - val_acc: 0.8408
# Epoch 10/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.5923 - acc: 0.8443 - val_loss: nan - val_acc: 0.8565
# Epoch 11/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.5266 - acc: 0.8587 - val_loss: nan - val_acc: 0.8722
# Epoch 12/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.4715 - acc: 0.8719 - val_loss: nan - val_acc: 0.8837
# Epoch 13/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.4270 - acc: 0.8827 - val_loss: nan - val_acc: 0.8937
# Epoch 14/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.3902 - acc: 0.8916 - val_loss: nan - val_acc: 0.9003
# Epoch 15/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.3603 - acc: 0.8989 - val_loss: nan - val_acc: 0.9077
# Epoch 16/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.3328 - acc: 0.9059 - val_loss: nan - val_acc: 0.9151
# Epoch 17/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.3091 - acc: 0.9121 - val_loss: nan - val_acc: 0.9204
# Epoch 18/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.2877 - acc: 0.9174 - val_loss: nan - val_acc: 0.9256
# Epoch 19/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.2678 - acc: 0.9230 - val_loss: nan - val_acc: 0.9311
# Epoch 20/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.2513 - acc: 0.9278 - val_loss: nan - val_acc: 0.9370
# Epoch 21/70
# 110288/110288 [==============================] - 17s 152us/step - loss: 0.2339 - acc: 0.9329 - val_loss: nan - val_acc: 0.9403
# Epoch 22/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.2213 - acc: 0.9367 - val_loss: nan - val_acc: 0.9448
# Epoch 23/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.2072 - acc: 0.9410 - val_loss: nan - val_acc: 0.9477
# Epoch 24/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1958 - acc: 0.9441 - val_loss: nan - val_acc: 0.9512
# Epoch 25/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1850 - acc: 0.9475 - val_loss: nan - val_acc: 0.9541
# Epoch 26/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1754 - acc: 0.9501 - val_loss: nan - val_acc: 0.9560
# Epoch 27/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1683 - acc: 0.9521 - val_loss: nan - val_acc: 0.9585
# Epoch 28/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1583 - acc: 0.9554 - val_loss: nan - val_acc: 0.9596
# Epoch 29/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1539 - acc: 0.9562 - val_loss: nan - val_acc: 0.9612
# Epoch 30/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1458 - acc: 0.9587 - val_loss: nan - val_acc: 0.9636
# Epoch 31/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1396 - acc: 0.9607 - val_loss: nan - val_acc: 0.9650
# Epoch 32/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1342 - acc: 0.9620 - val_loss: nan - val_acc: 0.9668
# Epoch 33/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1280 - acc: 0.9638 - val_loss: nan - val_acc: 0.9676
# Epoch 34/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1227 - acc: 0.9655 - val_loss: nan - val_acc: 0.9687
# Epoch 35/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1199 - acc: 0.9662 - val_loss: nan - val_acc: 0.9703
# Epoch 36/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1170 - acc: 0.9669 - val_loss: nan - val_acc: 0.9701
# Epoch 37/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1163 - acc: 0.9670 - val_loss: nan - val_acc: 0.9709
# Epoch 38/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1085 - acc: 0.9693 - val_loss: nan - val_acc: 0.9726
# Epoch 39/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.1054 - acc: 0.9701 - val_loss: nan - val_acc: 0.9729
# Epoch 40/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1036 - acc: 0.9705 - val_loss: nan - val_acc: 0.9737
# Epoch 41/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.1010 - acc: 0.9713 - val_loss: nan - val_acc: 0.9741
# Epoch 42/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0980 - acc: 0.9721 - val_loss: nan - val_acc: 0.9741
# Epoch 43/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0975 - acc: 0.9721 - val_loss: nan - val_acc: 0.9741
# Epoch 44/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0928 - acc: 0.9737 - val_loss: nan - val_acc: 0.9755
# Epoch 45/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0898 - acc: 0.9745 - val_loss: nan - val_acc: 0.9761
# Epoch 46/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.0863 - acc: 0.9755 - val_loss: nan - val_acc: 0.9770
# Epoch 47/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0848 - acc: 0.9759 - val_loss: nan - val_acc: 0.9772
# Epoch 48/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.0833 - acc: 0.9763 - val_loss: nan - val_acc: 0.9773
# Epoch 49/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.0802 - acc: 0.9773 - val_loss: nan - val_acc: 0.9784
# Epoch 50/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0806 - acc: 0.9770 - val_loss: nan - val_acc: 0.9774
# Epoch 51/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0791 - acc: 0.9774 - val_loss: nan - val_acc: 0.9786
# Epoch 52/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0755 - acc: 0.9785 - val_loss: nan - val_acc: 0.9791
# Epoch 53/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0747 - acc: 0.9787 - val_loss: nan - val_acc: 0.9796
# Epoch 54/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0722 - acc: 0.9795 - val_loss: nan - val_acc: 0.9792
# Epoch 55/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0723 - acc: 0.9793 - val_loss: nan - val_acc: 0.9800
# Epoch 56/70
# 110288/110288 [==============================] - 16s 149us/step - loss: 0.0715 - acc: 0.9795 - val_loss: nan - val_acc: 0.9790
# Epoch 57/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0696 - acc: 0.9800 - val_loss: nan - val_acc: 0.9804
# Epoch 58/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0664 - acc: 0.9810 - val_loss: nan - val_acc: 0.9805
# Epoch 59/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0670 - acc: 0.9808 - val_loss: nan - val_acc: 0.9803
# Epoch 60/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0665 - acc: 0.9809 - val_loss: nan - val_acc: 0.9801
# Epoch 61/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0660 - acc: 0.9809 - val_loss: nan - val_acc: 0.9806
# Epoch 62/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0640 - acc: 0.9816 - val_loss: nan - val_acc: 0.9815
# Epoch 63/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0618 - acc: 0.9822 - val_loss: nan - val_acc: 0.9815
# Epoch 64/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0601 - acc: 0.9827 - val_loss: nan - val_acc: 0.9822
# Epoch 65/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0588 - acc: 0.9831 - val_loss: nan - val_acc: 0.9824
# Epoch 66/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0588 - acc: 0.9830 - val_loss: nan - val_acc: 0.9814
# Epoch 67/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0593 - acc: 0.9828 - val_loss: nan - val_acc: 0.9823
# Epoch 68/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0563 - acc: 0.9837 - val_loss: nan - val_acc: 0.9826
# Epoch 69/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0559 - acc: 0.9838 - val_loss: nan - val_acc: 0.9828
# Epoch 70/70
# 110288/110288 [==============================] - 16s 148us/step - loss: 0.0538 - acc: 0.9844 - val_loss: nan - val_acc: 0.9831
# Sample 1:
# il a vu un vieux camion jaune <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Il a vu un vieux camion jaune
# Sample 2:
# new jersey est parfois calme pendant l' automne et il est neigeux en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# new jersey est parfois calme pendant l' automne et il est neigeux en avril <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %% [markdown]
# ## Submission
# When you're ready to submit, complete the following steps:
# 1. Review the [rubric](https://review.udacity.com/#!/rubrics/1004/view) to ensure your submission meets all requirements to pass
# 2. Generate an HTML version of this notebook
#
#   - Run the next cell to attempt automatic generation (this is the recommended method in Workspaces)
#   - Navigate to **FILE -> Download as -> HTML (.html)**
#   - Manually generate a copy using `nbconvert` from your shell terminal
# ```
# $ pip install nbconvert
# $ python -m nbconvert machine_translation.ipynb
# ```
#
# 3. Submit the project
#
#   - If you are in a Workspace, simply click the "Submit Project" button (bottom towards the right)
#
#   - Otherwise, add the following files into a zip archive and submit them
#   - `helper.py`
#   - `machine_translation.ipynb`
#   - `machine_translation.html`
#     - You can export the notebook by navigating to **File -> Download as -> HTML (.html)**.

# %% [markdown]
# ### Generate the html
#
# **Save your notebook before running the next cell to generate the HTML output.** Then submit your project.

# %%
# Save before you run this cell!
# !!jupyter nbconvert *.ipynb
# Out:
# ['[NbConvertApp] Converting notebook machine_translation.ipynb to html',
#  '[NbConvertApp] Writing 405191 bytes to machine_translation.html',
#  '[NbConvertApp] Converting notebook machine_translation-zh.ipynb to html',
#  '[NbConvertApp] Writing 328614 bytes to machine_translation-zh.html']

# %% [markdown]
# ## Optional Enhancements
#
# This project focuses on learning various network architectures for machine translation, but we don't evaluate the models according to best practices by splitting the data into separate test & training sets -- so the model accuracy is overstated. Use the [`sklearn.model_selection.train_test_split()`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) function to create separate training & test datasets, then retrain each of the models using only the training set and evaluate the prediction accuracy using the hold out test set. Does the "best" model change?
